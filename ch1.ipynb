# %% [markdown]
# # 1장

# %% [markdown]
# <table align="left">
#   <td>
#     <a href="https://colab.research.google.com/github/rickiepark/math4ds/blob/main/ch1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#   </td>
# </table>

# %%
import sympy

print('sympy', sympy.__version__)
# Out:
# sympy 1.13.1

# %% [markdown]
# 예제 1-1

# %%
my_value = 2 * (3 + 2)**2 / 5 - 4

print(my_value)
# Out:
# 6.0

# %% [markdown]
# 예제 1-2

# %%
my_value = 2 * ((3 + 2)**2 / 5) - 4

print(my_value)
# Out:
# 6.0

# %% [markdown]
# 예제 1-3

# %%
x = int(input("숫자를 입력하세요\n"))

product = 3 * x

print(product)
# Out:
# 숫자를 입력하세요
# 3
# 9

# %% [markdown]
# 예제 1-4

# %%
beta = 1.75
theta = 30.0

# %% [markdown]
# (역주)

# %%
β = 1.75
θ = 30.0

# %% [markdown]
# 예제 1-5

# %%
x1 = 3  # 또는 x_1 = 3
x2 = 10 # 또는 x_2 = 10
x3 = 44 # 또는 x_3 = 44

# %% [markdown]
# 예제 1-6

# %%
def f(x):
    return 2 * x + 1


x_values = [0, 1, 2, 3]

for x in x_values:
    y = f(x)
    print(y)
# Out:
# 1
# 3
# 5
# 7

# %% [markdown]
# 예제 1-7

# %%
from sympy import *

x = symbols('x')
f = 2*x + 1
plot(f)

# %% [markdown]
# 예제 1-8

# %%
from sympy import *

x = symbols('x')
f = x**2 + 1
plot(f)

# %% [markdown]
# 예제 1-9

# %%
from sympy import *
from sympy.plotting import plot3d

x, y = symbols('x y')
f = 2*x + 3*y
plot3d(f)

# %% [markdown]
# 예제 1-10

# %%
summation = sum(2*i for i in range(1,6))
print(summation)
# Out:
# 30

# %% [markdown]
# 예제 1-11

# %%
x = [1, 4, 6, 2]
n = len(x)

summation = sum(10*x[i] for i in range(0,n))
print(summation)
# Out:
# 130

# %% [markdown]
# (심파이의 합계)

# %%
from sympy import *

i,n = symbols('i n')

# 1부터 n까지 i를 반복하면서
# 2를 곱하고 더합니다
summation = Sum(2*i,(i,1,n))

# n을 5로 지정하면
# 숫자 1에서 5까지 반복합니다
up_to_5 = summation.subs(n, 5)
print(up_to_5.doit())
# Out:
# 30

# %% [markdown]
# 심파이로 표현식 간소화하기

# %%
from sympy import *

x = symbols('x')
expr = x**2 / x**5
print(expr)
# Out:
# x**(-3)

# %% [markdown]
# 예제 1-12

# %%
from math import log

# 2를 거듭제곱하여 8이 되는 지수는?
x = log(8, 2)

print(x)
# Out:
# 3.0

# %% [markdown]
# 예제 1-13

# %%
from math import exp

p = 100
r = .20
t = 2.0
n = 12

a = p * (1 + (r/n))**(n * t)

print(a)
# Out:
# 148.69146179463576

# %% [markdown]
# 예제 1-14

# %%
from math import exp

p = 100 # 원금, 시작 금액
r = .20 # 연이율
t = 2.0 # 기간, 연도

a = p * exp(r*t)

print(a)
# Out:
# 149.18246976412703

# %% [markdown]
# 예제 1-15

# %%
from math import log

# e를 거듭제곱하여 10이 되는 지수는?
x = log(10)

print(x)
# Out:
# 2.302585092994046

# %% [markdown]
# 예제 1-16

# %%
from sympy import *

x = symbols('x')
f = 1 / x
result = limit(f, x, oo)

print(result)
# Out:
# 0

# %%
from sympy import *

n = symbols('n')
f = (1 + (1/n))**n
result = limit(f, n, oo)

print(result) # E
print(result.evalf())
# Out:
# E
# 2.71828182845905

# %% [markdown]
# 예제 1-17

# %%
def derivative_x(f, x, step_size):
    m = (f(x + step_size) - f(x)) / ((x + step_size) - x)
    return m


def my_function(x):
    return x**2

slope_at_2 = derivative_x(my_function, 2, .00001)

print(slope_at_2)
# Out:
# 4.000010000000827

# %% [markdown]
# 예제 1-18

# %%
from sympy import *

# 'x'를 선언합니다
x = symbols('x')

# 파이썬 표현식을 사용해 함수를 정의합니다
f = x**2

# 이 함수의 도함수를 계산합니다
dx_f = diff(f)
print(dx_f)
# Out:
# 2*x

# %% [markdown]
# 예제 1-19

# %%
def f(x):
    return x**2

def d_f(x):
    return 2*x

slope_at_2 = d_f(2.0)

print(slope_at_2)
# Out:
# 4.0

# %% [markdown]
# 예제 1-20

# %%
# x = 2에서 기울기 계산하기
print(dx_f.subs(x,2))
# Out:
# 4

# %% [markdown]
# 예제 1-21

# %%
from sympy import *
from sympy.plotting import plot3d

# x와 y를 심파이에 선언합니다
x,y = symbols('x y')

# 파이썬 표현식을 사용해 함수를 정의합니다
f = 2*x**3 + 3*y**3

# x와 y에 대한 편도함수를 계산합니다
dx_f = diff(f, x)
dy_f = diff(f, y)

print(dx_f) # 6*x**2
print(dy_f) # 9*y**2

# 함수 그래프 그리기
plot3d(f)
# Out:
# 6*x**2
# 9*y**2

# %% [markdown]
# 예제 1-22

# %%
from sympy import *

# "x"와 스텝 크기 "s" 정의
x, s = symbols('x s')

# 함수 정의
f = x**2

# 간격 "s"만큼 떨어진 두 점을 기울기 공식에 대입합니다
slope_f = (f.subs(x, x + s) - f) / ((x+s) - x)

# x에 2를 대입합니다
slope_2 = slope_f.subs(x, 2)

# 스텝 크기 s가 0에 무한히 가까워질 때 x = 2에서 기울기를 계산합니다
result = limit(slope_2, s, 0)

print(result)
# Out:
# 4

# %% [markdown]
# 예제 1-23

# %%
from sympy import *

# "x"와 스텝 크기 "s" 정의
x, s = symbols('x s')

# 함수 정의
f = x**2

# 간격 "s"만큼 떨어진 두 점을 기울기 공식에 대입합니다
slope_f = (f.subs(x, x + s) - f) / ((x+s) - x)

# 스텝 크기 s가 0에 무한히 가까워질 때 도함수를 계산합니다
result = limit(slope_f, s, 0)

print(result)
# Out:
# 2*x

# %% [markdown]
# 예제 1-24

# %%
from sympy import *

x = symbols('x')

z = (x**2 + 1)**3 - 2
dz_dx = diff(z, x)
print(dz_dx)
# Out:
# 6*x*(x**2 + 1)**2

# %% [markdown]
# 예제 1-25

# %%
from sympy import *

x, y = symbols('x y')


# 첫 번째 함수의 도함수
# 충돌을 피하기 위해 _y로 씁니다
_y = x**2 + 1
dy_dx = diff(_y)

# 두 번째 도함수
z = y**3 - 2
dz_dy = diff(z)

# 연쇄 법칙을 사용한 경우와
# 대체 방식을 사용한 경우 도함수 계산
dz_dx_chain = (dy_dx * dz_dy).subs(y, _y)
dz_dx_no_chain = diff(z.subs(y, _y))

# 두 값이 같다는 것을 보임으로써 연쇄 법칙을 증명합니다
print(dz_dx_chain)
print(dz_dx_no_chain)
# Out:
# 6*x*(x**2 + 1)**2
# 6*x*(x**2 + 1)**2

# %% [markdown]
# 예제 1-26

# %%
def approximate_integral(a, b, n, f):
    delta_x = (b - a) / n
    total_sum = 0

    for i in range(1, n + 1):
        midpoint = 0.5 * (2 * a + delta_x * (2 * i - 1))
        total_sum += f(midpoint)

    return total_sum * delta_x

def my_function(x):
    return x**2 + 1

area = approximate_integral(a=0, b=1, n=5, f=my_function)

print(area)
# Out:
# 1.33

# %% [markdown]
# 예제 1-27

# %%
area = approximate_integral(a=0, b=1, n=1000, f=my_function)

print(area)
# Out:
# 1.333333250000001

# %% [markdown]
# 예제 1-28

# %%
area = approximate_integral(a=0, b=1, n=1_000_000, f=my_function)

print(area)
# Out:
# 1.3333333333332733

# %% [markdown]
# 예제 1-29

# %%
from sympy import *

# 심파이에 'x'를 선언합니다
x = symbols('x')

# 파이썬 표현식을 사용해 함수를 정의합니다
f = x**2 + 1

# x=0과 1 사이의 면적을 구하기 위해
# x에 대해서 함수의 적분을 계산합니다
area = integrate(f, (x, 0, 1))

print(area)
# Out:
# 4/3

# %% [markdown]
# 예제 1-30

# %%
from sympy import *

# 심파이에 변수를 선언합니다
x, i, n = symbols('x i n')

# 함수와 범위를 선언합니다
f = x**2 + 1
lower, upper = 0, 1

# 상자의 너비와 "i" 위치에 있는 직사각형의 높이를 계산합니다
delta_x = ((upper - lower) / n)
x_i = (lower + delta_x * i)
fx_i = f.subs(x, x_i)

# "n" 개의 직사각형을 순환하면서 면적을 더합니다
n_rectangles = Sum(delta_x * fx_i, (i, 1, n)).doit()

# 직사각형의 개수 "n"을 무한대로 늘려 면적을 계산합니다
area = limit(n_rectangles, n, oo)

print(area)
# Out:
# 4/3
